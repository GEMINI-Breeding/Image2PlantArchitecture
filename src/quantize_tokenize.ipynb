# %% [markdown]
# 데이터셋을 모두 불러 들여, Plant Vector 데이터셋을 만든다. 아마도 Plant Vector 데이터셋은 서로 다른 수만개의 벡터
# 그 다음 100개의 대표 케이스를 만들고 퀀타이제이션한다.
# 퀀타이제이션 한 다음 원본 데이터를 표현해보고 에러를 계산한다.
# 에러가 만족 할 만큼 작다면 100개 + Special Token 으로 마무리한다.
