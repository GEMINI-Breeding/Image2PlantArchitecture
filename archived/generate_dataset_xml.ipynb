# %%
import os
import shutil
import sys
import subprocess

# %%
program_path = "../src/GenerateDataset/build"

# Dataset Path
dataset_path = "../data/generated_Dec10_2024"

# Clean the dataset directory
if os.path.exists(dataset_path):
    shutil.rmtree(dataset_path)

# Create the dataset directory
if not os.path.exists(dataset_path):
    os.makedirs(dataset_path)

# Create images directory
images_path = dataset_path + "/images"
if not os.path.exists(images_path):
    os.makedirs(images_path)

# Create xml files directory
xml_path = dataset_path + "/xml"
if not os.path.exists(xml_path):
    os.makedirs(xml_path)

output_path = "output"
# Get absolute path
output_path = os.path.abspath(output_path)

# %%
n_iter = 100

# If the system is Linux, export DISPLAY
if sys.platform != "Darwin":
    os.environ["DISPLAY"] = ":11"

# Remove and recreate output folder
shutil.rmtree(output_path, ignore_errors=True)
os.makedirs(output_path, exist_ok=True)

# Generate dataset
for i in range(n_iter):
    print("Generating image: ", i)
    seed = i + 1
    image_name = f"cowpea_{i:04d}" 
    # Generate image 
    # Construct the command
    command = ""
    command += f"cd {program_path} && ./main " 
    command += f"-h 1.0 -o {output_path} -seed {seed} -name {image_name} -xml -tile black -g"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)


    # Check if the command was successful
    if result.returncode == 0:
        # print("Command executed successfully")
        print(result.stdout)  # Print the standard output
        pass
    else:
        print(result.stdout)  # Print the standard output
        print(result.stderr)  # Print the error output
        raise("Command failed")
        pass
# Out:
# Generating image:  0
# Save dir: /home/lion397/codes/Image2PlantArchitecture/src/output
# Seed: 1
# Output name: cowpea_0000
# Debug: false
# Grow: true
# View height: 1m
# Tile file: black
# Initializing graphics...done.
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_00.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_01.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_02.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_03.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_04.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_05.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_06.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_07.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_08.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_09.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_10.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_11.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_12.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_13.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_14.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_15.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_16.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_17.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_18.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0000_day_19.jpeg
#
# Generating image:  1
# Save dir: /home/lion397/codes/Image2PlantArchitecture/src/output
# Seed: 2
# Output name: cowpea_0001
# Debug: false
# Grow: true
# View height: 1m
# Tile file: black
# Initializing graphics...done.
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_00.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_01.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_02.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_03.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_04.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_05.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_06.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_07.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_08.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_09.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_10.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_11.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_12.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_13.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_14.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_15.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_16.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_17.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_18.jpeg
# writing JPEG image: /home/lion397/codes/Image2PlantArchitecture/src/output/cowpea_0001_day_19.jpeg
#
# Generating image:  2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 21
#      19 command += f"cd {program_path} && ./main "
#      20 command += f"-h 1.0 -o {output_path} -seed {seed} -name {image_name} -xml -tile black -g"
# ---> 21 result = subprocess.run(command, shell=True, capture_output=True, text=True)
#      24 # Check if the command was successful
#      25 if result.returncode == 0:
#      26     # print("Command executed successfully")
#
# File ~/codes/Image2PlantArchitecture/.env/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/codes/Image2PlantArchitecture/.env/lib/python3.8/subprocess.py:1028, in Popen.communicate(self, input, timeout)
#    1025     endtime = None
#    1027 try:
# -> 1028     stdout, stderr = self._communicate(input, endtime, timeout)
#    1029 except KeyboardInterrupt:
#    1030     # https://bugs.python.org/issue25942
#    1031     # See the detailed comment in .wait().
#    1032     if timeout is not None:
#
# File ~/codes/Image2PlantArchitecture/.env/lib/python3.8/subprocess.py:1884, in Popen._communicate(self, input, endtime, orig_timeout)
#    1877     self._check_timeout(endtime, orig_timeout,
#    1878                         stdout, stderr,
#    1879                         skip_check_and_raise=True)
#    1880     raise RuntimeError(  # Impossible :)
#    1881         '_check_timeout(..., skip_check_and_raise=True) '
#    1882         'failed to raise TimeoutExpired.')
# -> 1884 ready = selector.select(timeout)
#    1885 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1887 # XXX Rewrite these to use non-blocking I/O on the file
#    1888 # objects; they are no longer using C stdio!
#
# File ~/codes/Image2PlantArchitecture/.env/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
import os
import subprocess
import concurrent.futures
from tqdm import tqdm

# Function to re-render a single XML file
def re_render_xml(filename):
    if filename.endswith(".xml"):
        image_name = filename.split(".")[0]
        # Generate image 
        # Construct the command
        command = ""
        command += f"cd {program_path} && ./main " 
        command += f"-h 1.0 -o {output_path} -name {image_name} -tile black -f {os.path.join(output_path, filename)}"
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        return result

# Re-render XML files in parallel with progress bar
with concurrent.futures.ThreadPoolExecutor() as executor:
    xml_list = os.listdir(output_path)
    xml_list.sort()
    futures = [executor.submit(re_render_xml, filename) for filename in xml_list if filename.endswith(".xml")]
    
    # Use tqdm to show progress bar
    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures), desc="Re-rendering XML files"):
        result = future.result()
        # Check if the command was successful
        if result.returncode != 0:
            print(result.stdout)  # Print the standard output
            print(result.stderr)  # Print the error output
            raise Exception("Command failed")
# Out:
# Re-rendering XML files: 100%|██████████| 2000/2000 [06:28<00:00,  5.15it/s]

# %%
# List jpg and xml files and move them to the dataset directory
for filename in os.listdir(output_path):
    if filename.endswith(".jpeg"):
        shutil.move(os.path.join(output_path, filename), images_path)
    elif filename.endswith(".xml"):
        shutil.move(os.path.join(output_path, filename), xml_path)

# %%
# Test loading the generated dataset
from plant_dataset import PlantDataset 
# Show some images
import matplotlib.pyplot as plt
import numpy as np
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from plant_dataset import collate_fn
transform = transforms.Compose([
                        transforms.ToTensor(),
                        # transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
        ])
train_dataset = PlantDataset("../data/generated_Nov14_20224", load_depth=False, preload=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, collate_fn=collate_fn)
import cv2
n = 5
for i in range(n):
    #image, vecs, _ = train_dataset[-i-1]
    #image, vecs, _ = train_dataset[i]
    image, vecs, _ = next(iter(train_loader))
    image = image.permute(1, 2, 0)
    image_rgb = image[:, :, :3]
    img = cv2.normalize(np.array(image_rgb.cpu()), None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    # img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(img)
    plt.title(f"Image {i}")
    plt.axis('off')

    if train_dataset.load_depth:
        image_depth = image[:, :, 3]
        img = cv2.normalize(np.array(image_depth.cpu()), None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
        plt.subplot(5, 2, 2*i+2)
        plt.imshow(img, cmap='gray')
        plt.title("Depth")
        plt.axis('off')
# Out:
# Total 300 images and plant strings loaded
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 22
#      18 n = 5
#      19 for i in range(n):
#      20     #image, vecs, _ = train_dataset[-i-1]
#      21     #image, vecs, _ = train_dataset[i]
# ---> 22     image, vecs, _ = next(iter(train_loader))
#      23     image = image.permute(1, 2, 0)
#      24     image_rgb = image[:, :, :3]
#
# File ~/Library/CloudStorage/SynologyDrive-NVME/codes_2024_work/Image2PlantArchitecture/.env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/Library/CloudStorage/SynologyDrive-NVME/codes_2024_work/Image2PlantArchitecture/.env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Library/CloudStorage/SynologyDrive-NVME/codes_2024_work/Image2PlantArchitecture/.env/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~/Library/CloudStorage/SynologyDrive-NVME/codes_2024_work/Image2PlantArchitecture/src/plant_dataset.py:168, in collate_fn(batch)
#     166 max_length = max(lengths)
#     167 # Check if the vectors are 1 dimensional
# --> 168 if len(vectors[0].shape) == 1:
#     169     vectors_padded = np.ones((len(vectors), max_length), dtype=int) * PAD_token
#     170 else:
#     171     # vectors_padded = np.ones((len(vectors), max_length, 1+5+3+2+4)) * PAD_token
#
# AttributeError: 'NoneType' object has no attribute 'shape'
